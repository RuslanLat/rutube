# %% [markdown]
# в случае отсутствия установить библиотеку \
# pip install pandas

# %%
# импорт необходимых библиотек
import pickle 
import pandas as pd

# %% [markdown]
# В данных для задачи "Предсказание социально-демографических характеристик пользователя" в колонке **event_timestamp** указано московское время (GMT +3). \
# Используя данные из колонки **region** приводится время к региональному

# %%
# загрузка данных с историей просмотров пользователей
all_events = pd.read_csv("data/all_events.csv")
all_events.head()
# Out:
#              event_timestamp                  region ua_device_type  \
# 0  2024-06-01 13:08:30+03:00      Tatarstan Republic     smartphone
# 1  2024-06-01 14:30:00+03:00  Bashkortostan Republic     smartphone
# 2  2024-06-01 18:48:12+03:00      Novosibirsk Oblast     smartphone
# 3  2024-06-01 16:32:36+03:00                  Moscow        desktop
# 4  2024-06-01 00:57:04+03:00           Moscow Oblast     smartphone
#
#   ua_client_type    ua_os  ua_client_name  total_watchtime rutube_video_id  \
# 0        browser  Android   Chrome Mobile               60    video_395879
# 1     mobile app  Android          Rutube               60    video_216518
# 2     mobile app  Android          Rutube              121     video_41225
# 3        browser  Windows  Yandex Browser             2324    video_215886
# 4     mobile app  Android          Rutube             6830     video_43631
#
#    viewer_uid
# 0    10813370
# 1    10512324
# 2    10951137
# 3    10912434
# 4    10223585

# %%
# загрузка данных с историей просмотров пользователей с известными целевыми переменными
train_events = pd.read_csv("data/train_events.csv")
train_events.head()
# Out:
#              event_timestamp                  region ua_device_type  \
# 0  2024-06-01 06:40:58+03:00             Chelyabinsk        desktop
# 1  2024-06-01 19:33:24+03:00  Bashkortostan Republic     smartphone
# 2  2024-06-01 21:30:43+03:00          St.-Petersburg        desktop
# 3  2024-06-01 23:03:42+03:00                  Moscow     smartphone
# 4  2024-06-01 22:48:09+03:00                  Moscow     smartphone
#
#   ua_client_type    ua_os  ua_client_name  total_watchtime rutube_video_id  \
# 0        browser  Windows  Yandex Browser             1883    video_133074
# 1     mobile app  Android          Rutube              512    video_362960
# 2        browser  Windows          Chrome             5647     video_96775
# 3     mobile app  Android          Rutube             1521    video_161610
# 4     mobile app  Android          Rutube               71    video_116245
#
#    viewer_uid
# 0    10067243
# 1    10245341
# 2    10894333
# 3    10029092
# 4    10452976

# %%
# получение списка уникальных названий регионов
all_regions = list(set(all_events["region"].unique()) | set(train_events["region"].unique()))
all_regions[:5]
# Out:
# ['Kursk Oblast',
#  'Ulyanovsk',
#  'Volgograd Oblast',
#  'Novgorod Oblast',
#  'Tambov Oblast']

# %% [markdown]
# В данных названия региона ***присутствуют*** как и название региона, так и название регионального центра. \
# Необходимо ***привести*** название колонки **region** к единому формату. \
# В качестве идентичного название ***предлагается выбрать*** название регионального центра региона.

# %%
# количество уникальных регионов
len(all_regions)
# Out:
# 116

# %% [markdown]
# Для приведения названия **регионов** в единый формат использовалось расширение VC Code **ChatGPT GPT-4o - Bito AI Code Assistant** v1.4.0
#
# ***Примечание:*** необходима предварительная регистрация на сайте https://openai.com/

# %% [markdown]
# Формирование словаря где ключ исходное название региона, а значение новое название (название регионального центра региона)
#
# ***Примечание:*** Использовался промт
# > сделай словарь где ключь будет уникальное название из списка, \
# а в значении столица указанного региона на русском языке, если указан город, \
# и он является столицей региона, осталвяем его на русском языке

# %%
# полученный ответ от ChatGPT
ru_regions_dict = {
    "Chelyabinsk": "Челябинск",
    "Irkutsk Oblast": "Иркутск",
    "St.-Petersburg": "Санкт-Петербург",
    "Tver Oblast": "Тверь",
    "Rostov": "Ростов-на-Дону",
    "Nizhny Novgorod Oblast": "Нижний Новгород",
    "Novosibirsk Oblast": "Новосибирск",
    "Kaliningrad Oblast": "Калининград",
    "Udmurtiya Republic": "Ижевск",
    "Vladimir Oblast": "Владимир",
    "Omsk Oblast": "Омск",
    "Moscow Oblast": "Москва",
    "Moscow": "Москва",
    "Bashkortostan Republic": "Уфа",
    "Ryazan Oblast": "Рязань",
    "Mariy-El Republic": "Йошкар-Ола",
    "Sverdlovsk": "Екатеринбург",
    "Khakasiya Republic": "Абакан",
    "Ulyanovsk": "Ульяновск",
    "Tomsk Oblast": "Томск",
    "Amur Oblast": "Благовещенск",
    "Kuzbass": "Кемерово",
    "Saratov Oblast": "Саратов",
    "Tatarstan Republic": "Казань",
    "Samara Oblast": "Самара",
    "Sakha": "Якутск",
    "Orenburg Oblast": "Оренбург",
    "Khanty-Mansia": "Ханты-Мансийск",
    "Komi": "Сыктывкар",
    "Krasnodar Krai": "Краснодар",
    "Primorye": "Владивосток",
    "Yaroslavl Oblast": "Ярославль",
    "Perm Krai": "Пермь",
    "Arkhangelskaya": "Архангельск",
    "Dagestan": "Махачкала",
    "Sverdlovsk Oblast": "Екатеринбург",
    "Mordoviya Republic": "Саранск",
    "Astrakhan Oblast": "Астрахань",
    "Lipetsk Oblast": "Липецк",
    "Leningradskaya Oblast'": 'Санкт-Петербург',
    "North Ossetia–Alania": "Владикавказ",
    "Tula Oblast": "Тула",
    "Kursk Oblast": "Курск",
    "Altay Kray": "Барнаул",
    "Kirov Oblast": "Киров",
    "Tambov Oblast": "Тамбов",
    "Stavropol Kray": "Ставрополь",
    "Karelia": "Петрозаводск",
    "Bryansk Oblast": "Брянск",
    "Krasnodarskiy": "Краснодар",
    "Khabarovsk": "Хабаровск",
    "Murmansk": "Мурманск",
    "Novgorod Oblast": "Великий Новгород",
    "Tula": "Тула",
    "Krasnoyarsk Krai": "Красноярск",
    "Vologda Oblast": "Вологда",
    "Belgorod Oblast": "Белгород",
    "Kamchatka": "Петропавловск-Камчатский",
    "Voronezh Oblast": "Воронеж",
    "Penza Oblast": "Пенза",
    "Tyumen Oblast": "Тюмень",
    "Magadan Oblast": "Магадан",
    "Chuvashia": "Чебоксары",
    "Kostroma Oblast": "Кострома",
    "Sakhalin Oblast": "Южно-Сахалинск",
    "Transbaikal Territory": "Чита",
    "Adygeya Republic": "Майкоп",
    "Oryol oblast": "Орёл",
    "Buryatiya Republic": "Улан-Удэ",
    "Tambov": "Тамбов",
    "Kemerovo Oblast": "Кемерово",
    "Chukotka": "Анадырь",
    "Volgograd Oblast": "Волгоград",
    "Chechnya": "Грозный",
    "Smolensk Oblast": "Смоленск",
    "Kurgan Oblast": "Курган",
    "Kaliningrad": "Калининград",
    "Zabaykalskiy (Transbaikal) Kray": "Чита",
    "Pskov Oblast": "Псков",
    "Saratovskaya Oblast": "Саратов",
    "Ivanovo": "Иваново",
    "Yamalo-Nenets": "Салехард",
    "Ivanovo Oblast": "Иваново",
    "Karachayevo-Cherkesiya Republic": "Черкесск",
    "Tyumen’ Oblast": "Тюмень",
    "Kaluga Oblast": "Калуга",
    "Orel Oblast": "Орёл",
    "Stavropol’ Kray": "Ставрополь",
    "Altai": "Горно-Алтайск",
    "Crimea": "Симферополь",
    "Penza": "Пенза",
    "Kabardino-Balkariya Republic": "Нальчик",
    "Sebastopol City": "Севастополь",
    "Kirov": "Киров",
    "Kursk": "Курск",
    "Kalmykiya Republic": "Элиста",
    "Voronezj": "Воронеж",
    "Jaroslavl": "Ярославль",
    "Tver’ Oblast": "Тверь",
    "Kaluga": "Калуга",
    "Nenets": "Нарьян-Мар",
    "Krasnoyarskiy": "Красноярск",
    "Smolenskaya Oblast’": "Смоленск",
    "Vladimir": "Владимир",
    "Perm": "Пермь",
    "Vologda": "Вологда",
    "Omsk": "Омск",
    "Smolensk": "Смоленск",
    "North Ossetia": "Владикавказ",
    "Primorskiy (Maritime) Kray": "Владивосток",
    "Stavropol Krai": "Ставрополь",
    "Tyva Republic": "Кызыл",
    "Astrakhan": "Астрахань",
    "Jewish Autonomous Oblast": "Биробиджан",
    "Ingushetiya Republic": "Назрань",
    "Arkhangelsk Oblast": "Архангельск"
}

# %%
# сохранение данных в файл
with open("data/ru_regions_dict.pkl", "wb") as f:
    pickle.dump(ru_regions_dict, f)

# %%
# with open("data/ru_regions_dict.pkl", 'rb') as f:
#     ru_regions_dict = pickle.load(f)

# %% [markdown]
# Формирование словаря где ключ новое название (название регионального центра региона), а значение данные временной зоны и геокоординаты региона
#
# ***Примечание:*** Использовался промт
# > исправь словарь чтоб ключем стало значение, а в значении добавь часовой пояс и координаты

# %%
# полученный ответ от ChatGPT
data_regions_dict = {
    'Челябинск': {'timezone': 'UTC+5', 'coordinates': (55.1644, 61.4368)},
    'Иркутск': {'timezone': 'UTC+8', 'coordinates': (52.2833, 104.3000)},
    'Санкт-Петербург': {'timezone': 'UTC+3', 'coordinates': (59.9343, 30.3351)},
    'Тверь': {'timezone': 'UTC+3', 'coordinates': (56.8580, 35.9113)},
    'Ростов-на-Дону': {'timezone': 'UTC+3', 'coordinates': (47.2225, 39.7182)},
    'Нижний Новгород': {'timezone': 'UTC+3', 'coordinates': (56.3269, 44.0059)},
    'Новосибирск': {'timezone': 'UTC+7', 'coordinates': (55.0084, 82.9357)},
    'Калининград': {'timezone': 'UTC+2', 'coordinates': (54.7104, 20.4522)},
    'Ижевск': {'timezone': 'UTC+4', 'coordinates': (56.8526, 53.2112)},
    'Владимир': {'timezone': 'UTC+3', 'coordinates': (56.1290, 40.4065)},
    'Омск': {'timezone': 'UTC+7', 'coordinates': (54.9923, 73.3686)},
    'Москва': {'timezone': 'UTC+3', 'coordinates': (55.7558, 37.6173)},
    'Уфа': {'timezone': 'UTC+5', 'coordinates': (54.7388, 55.9721)},
    'Рязань': {'timezone': 'UTC+3', 'coordinates': (54.6090, 39.7373)},
    'Йошкар-Ола': {'timezone': 'UTC+3', 'coordinates': (56.6354, 47.8685)},
    'Екатеринбург': {'timezone': 'UTC+5', 'coordinates': (56.8389, 60.6057)},
    'Абакан': {'timezone': 'UTC+7', 'coordinates': (53.7167, 91.4295)},
    'Ульяновск': {'timezone': 'UTC+4', 'coordinates': (54.3520, 48.3663)},
    'Томск': {'timezone': 'UTC+7', 'coordinates': (56.5013, 84.9742)},
    'Благовещенск': {'timezone': 'UTC+9', 'coordinates': (50.2833, 127.5333)},
    'Кемерово': {'timezone': 'UTC+7', 'coordinates': (54.8619, 86.0750)},
    'Саратов': {'timezone': 'UTC+4', 'coordinates': (51.5826, 45.9649)},
    'Казань': {'timezone': 'UTC+3', 'coordinates': (55.8304, 49.0661)},
    'Самара': {'timezone': 'UTC+4', 'coordinates': (53.1959, 50.1002)},
    'Якутск': {'timezone': 'UTC+9', 'coordinates': (62.0333, 129.7333)},
    'Оренбург': {'timezone': 'UTC+5', 'coordinates': (51.7690, 58.6075)},
    'Ханты-Мансийск': {'timezone': 'UTC+5', 'coordinates': (61.0022, 69.0145)},
    'Сыктывкар': {'timezone': 'UTC+3', 'coordinates': (61.6693, 50.8347)},
    'Краснодар': {'timezone': 'UTC+3', 'coordinates': (45.0355, 38.9753)},
    'Владивосток': {'timezone': 'UTC+10', 'coordinates': (43.1156, 131.8851)},
    'Ярославль': {'timezone': 'UTC+3', 'coordinates': (57.6261, 39.8854)},
    'Пермь': {'timezone': 'UTC+5', 'coordinates': (58.0105, 56.2504)},
    'Архангельск': {'timezone': 'UTC+3', 'coordinates': (64.5370, 40.5150)},
    'Махачкала': {'timezone': 'UTC+3', 'coordinates': (42.9850, 47.5045)},
    'Саранск': {'timezone': 'UTC+3', 'coordinates': (54.1833, 45.1667)},
    'Астрахань': {'timezone': 'UTC+4', 'coordinates': (46.3498, 48.0480)},
    'Липецк': {'timezone': 'UTC+3', 'coordinates': (52.6010, 39.5739)},
    'Санкт-Петербург': {'timezone': 'UTC+3', 'coordinates': (59.9343, 30.3351)},
    'Владикавказ': {'timezone': 'UTC+3', 'coordinates': (43.0235, 44.6863)},
    'Тула': {'timezone': 'UTC+3', 'coordinates': (54.1971, 37.6135)},
    'Курск': {'timezone': 'UTC+3', 'coordinates': (51.7388, 36.1874)},
    'Барнаул': {'timezone': 'UTC+7', 'coordinates': (53.3460, 83.7779)},
    'Киров': {'timezone': 'UTC+3', 'coordinates': (58.6036, 49.6660)},
    'Тамбов': {'timezone': 'UTC+3', 'coordinates': (52.7311, 41.4423)},
    'Ставрополь': {'timezone': 'UTC+3', 'coordinates': (45.0443, 41.9684)},
    'Петрозаводск': {'timezone': 'UTC+3', 'coordinates': (61.7850, 34.3645)},
    'Брянск': {'timezone': 'UTC+3', 'coordinates': (52.9655, 33.8712)},
    'Хабаровск': {'timezone': 'UTC+9', 'coordinates': (48.4820, 135.0667)},
    'Мурманск': {'timezone': 'UTC+3', 'coordinates': (68.9585, 33.0782)},
    'Великий Новгород': {'timezone': 'UTC+3', 'coordinates': (58.5161, 31.2756)},
    'Красноярск': {'timezone': 'UTC+7', 'coordinates': (56.0153, 92.8932)},
    'Вологда': {'timezone': 'UTC+3', 'coordinates': (59.2243, 39.8910)},
    'Белгород': {'timezone': 'UTC+3', 'coordinates': (50.6050, 36.5762)},
    'Петропавловск-Камчатский': {'timezone': 'UTC+12', 'coordinates': (53.0000, 158.6500)},
    'Воронеж': {'timezone': 'UTC+3', 'coordinates': (51.6602, 39.1972)},
    'Пенза': {'timezone': 'UTC+3', 'coordinates': (53.1978, 45.0162)},
    'Тюмень': {'timezone': 'UTC+5', 'coordinates': (57.1522, 65.5272)},
    'Магадан': {'timezone': 'UTC+10', 'coordinates': (59.5708, 150.8022)},
    'Чебоксары': {'timezone': 'UTC+3', 'coordinates': (56.1300, 47.2510)},
    'Кострома': {'timezone': 'UTC+3', 'coordinates': (57.7713, 40.9261)},
    'Южно-Сахалинск': {'timezone': 'UTC+10', 'coordinates': (46.9564, 142.7338)},
    'Чита': {'timezone': 'UTC+9', 'coordinates': (52.0333, 113.5000)},
    'Майкоп': {'timezone': 'UTC+3', 'coordinates': (44.6053, 40.0970)},
    'Орёл': {'timezone': 'UTC+3', 'coordinates': (52.9735, 36.1108)},
    'Улан-Удэ': {'timezone': 'UTC+8', 'coordinates': (51.8333, 107.5833)},
    'Кемерово': {'timezone': 'UTC+7', 'coordinates': (54.8619, 86.0750)},
    'Анадырь': {'timezone': 'UTC+12', 'coordinates': (64.7333, 177.4667)},
    'Волгоград': {'timezone': 'UTC+4', 'coordinates': (48.7080, 44.5130)},
    'Грозный': {'timezone': 'UTC+3', 'coordinates': (43.3101, 45.6986)},
    'Смоленск': {'timezone': 'UTC+3', 'coordinates': (54.7865, 30.9734)},
    'Курган': {'timezone': 'UTC+5', 'coordinates': (55.4261, 65.3392)},
    'Чита': {'timezone': 'UTC+9', 'coordinates': (52.0333, 113.5000)},
    'Псков': {'timezone': 'UTC+3', 'coordinates': (57.8261, 28.3480)},
    'Саратов': {'timezone': 'UTC+4', 'coordinates': (51.5826, 45.9649)},
    'Иваново': {'timezone': 'UTC+3', 'coordinates': (57.0015, 40.9743)},
    'Салехард': {'timezone': 'UTC+5', 'coordinates': (66.5350, 66.5667)},
    'Иваново': {'timezone': 'UTC+3', 'coordinates': (57.0015, 40.9743)},
    'Черкесск': {'timezone': 'UTC+3', 'coordinates': (44.2231, 41.6000)},
    'Тюмень': {'timezone': 'UTC+5', 'coordinates': (57.1522, 65.5272)},
    'Калуга': {'timezone': 'UTC+3', 'coordinates': (54.5145, 36.2632)},
    'Орёл': {'timezone': 'UTC+3', 'coordinates': (52.9735, 36.1108)},
    'Ставрополь': {'timezone': 'UTC+3', 'coordinates': (45.0443, 41.9684)},
    'Горно-Алтайск': {'timezone': 'UTC+7', 'coordinates': (51.9650, 85.9470)},
    'Симферополь': {'timezone': 'UTC+3', 'coordinates': (44.9521, 34.1024)},
    'Пенза': {'timezone': 'UTC+3', 'coordinates': (53.1978, 45.0162)},
    'Нальчик': {'timezone': 'UTC+3', 'coordinates': (43.4871, 43.6854)},
    'Севастополь': {'timezone': 'UTC+3', 'coordinates': (44.6165, 33.5255)},
    'Киров': {'timezone': 'UTC+3', 'coordinates': (58.6036, 49.6660)},
    'Курск': {'timezone': 'UTC+3', 'coordinates': (51.7388, 36.1874)},
    'Элиста': {'timezone': 'UTC+3', 'coordinates': (46.3074, 44.2695)},
    'Воронеж': {'timezone': 'UTC+3', 'coordinates': (51.6602, 39.1972)},
    'Ярославль': {'timezone': 'UTC+3', 'coordinates': (57.6261, 39.8854)},
    'Тверь': {'timezone': 'UTC+3', 'coordinates': (56.8580, 35.9113)},
    'Калуга': {'timezone': 'UTC+3', 'coordinates': (54.5145, 36.2632)},
    'Нарьян-Мар': {'timezone': 'UTC+3', 'coordinates': (67.6350, 53.0050)},
    'Красноярск': {'timezone': 'UTC+7', 'coordinates': (56.0153, 92.8932)},
    'Смоленск': {'timezone': 'UTC+3', 'coordinates': (54.7865, 30.9734)},
    'Владимир': {'timezone': 'UTC+3', 'coordinates': (56.1290, 40.4065)},
    'Пермь': {'timezone': 'UTC+5', 'coordinates': (58.0105, 56.2504)},
    'Вологда': {'timezone': 'UTC+3', 'coordinates': (59.2243, 39.8910)},
    'Омск': {'timezone': 'UTC+7', 'coordinates': (54.9923, 73.3686)},
    'Смоленск': {'timezone': 'UTC+3', 'coordinates': (54.7865, 30.9734)},
    'Владикавказ': {'timezone': 'UTC+3', 'coordinates': (43.0235, 44.6863)},
    'Владивосток': {'timezone': 'UTC+10', 'coordinates': (43.1156, 131.8851)},
    'Ставрополь': {'timezone': 'UTC+3', 'coordinates': (45.0443, 41.9684)},
    'Кызыл': {'timezone': 'UTC+7', 'coordinates': (51.7221, 94.4530)},
    'Астрахань': {'timezone': 'UTC+4', 'coordinates': (46.3498, 48.0480)},
    'Биробиджан': {'timezone': 'UTC+10', 'coordinates': (48.7833, 132.9167)},
    'Назрань': {'timezone': 'UTC+3', 'coordinates': (43.2336, 44.7733)},
    'Архангельск': {'timezone': 'UTC+3', 'coordinates': (64.5370, 40.5150)},
}

# %%
# сохранение данных в файл
with open("data/data_regions_dict.pkl", "wb") as f:
    pickle.dump(data_regions_dict, f)

# %%
# формирование Data Frame названий регионов
all_regions_df = pd.DataFrame(all_regions, columns=["Регион en"])
all_regions_df.head()
# Out:
#           Регион en
# 0      Kursk Oblast
# 1         Ulyanovsk
# 2  Volgograd Oblast
# 3   Novgorod Oblast
# 4     Tambov Oblast

# %%
# получение нового признака - название регионального центра на русском языке
all_regions_df["Регион ru"] = all_regions_df["Регион en"].map(ru_regions_dict)

# %%
# получение нового признака - временная зона региона и геокоординаты
all_regions_df["data_regions_dict"] = all_regions_df["Регион ru"].map(data_regions_dict)

# %%
# вывод данных
all_regions_df.head()
# Out:
#           Регион en         Регион ru  \
# 0      Kursk Oblast             Курск
# 1         Ulyanovsk         Ульяновск
# 2  Volgograd Oblast         Волгоград
# 3   Novgorod Oblast  Великий Новгород
# 4     Tambov Oblast            Тамбов
#
#                                    data_regions_dict
# 0  {'timezone': 'UTC+3', 'coordinates': (51.7388,...
# 1  {'timezone': 'UTC+4', 'coordinates': (54.352, ...
# 2  {'timezone': 'UTC+4', 'coordinates': (48.708, ...
# 3  {'timezone': 'UTC+3', 'coordinates': (58.5161,...
# 4  {'timezone': 'UTC+3', 'coordinates': (52.7311,...

# %%
# извлечение признаков - временная зона региона и геокоординаты
all_regions_df["timezone"] = all_regions_df["data_regions_dict"].apply(lambda x: x["timezone"])
all_regions_df["lat"] = all_regions_df["data_regions_dict"].apply(lambda x: x["coordinates"][0])
all_regions_df["lon"] = all_regions_df["data_regions_dict"].apply(lambda x: x["coordinates"][1])

# %%
# вывод данных
all_regions_df.head()
# Out:
#           Регион en         Регион ru  \
# 0      Kursk Oblast             Курск
# 1         Ulyanovsk         Ульяновск
# 2  Volgograd Oblast         Волгоград
# 3   Novgorod Oblast  Великий Новгород
# 4     Tambov Oblast            Тамбов
#
#                                    data_regions_dict timezone      lat  \
# 0  {'timezone': 'UTC+3', 'coordinates': (51.7388,...    UTC+3  51.7388
# 1  {'timezone': 'UTC+4', 'coordinates': (54.352, ...    UTC+4  54.3520
# 2  {'timezone': 'UTC+4', 'coordinates': (48.708, ...    UTC+4  48.7080
# 3  {'timezone': 'UTC+3', 'coordinates': (58.5161,...    UTC+3  58.5161
# 4  {'timezone': 'UTC+3', 'coordinates': (52.7311,...    UTC+3  52.7311
#
#        lon
# 0  36.1874
# 1  48.3663
# 2  44.5130
# 3  31.2756
# 4  41.4423

# %%
# проверка на наличие пропусков
all_regions_df.isna().sum()
# Out:
# Регион en            0
# Регион ru            0
# data_regions_dict    0
# timezone             0
# lat                  0
# lon                  0
# dtype: int64

# %% [markdown]
# Пропусков в данных **нет**

# %%
# проверка на соответствие типов данных
all_regions_df.dtypes
# Out:
# Регион en             object
# Регион ru             object
# data_regions_dict     object
# timezone              object
# lat                  float64
# lon                  float64
# dtype: object

# %% [markdown]
# Типы данных **релевантные**

# %%
# удаление вспомогательного признака
all_regions_df.drop(columns=["data_regions_dict"], inplace=True)

# %%
# вывод данных
all_regions_df.head()
# Out:
#           Регион en         Регион ru timezone      lat      lon
# 0      Kursk Oblast             Курск    UTC+3  51.7388  36.1874
# 1         Ulyanovsk         Ульяновск    UTC+4  54.3520  48.3663
# 2  Volgograd Oblast         Волгоград    UTC+4  48.7080  44.5130
# 3   Novgorod Oblast  Великий Новгород    UTC+3  58.5161  31.2756
# 4     Tambov Oblast            Тамбов    UTC+3  52.7311  41.4423

# %%
# размерность данных
all_regions_df.shape
# Out:
# (116, 5)

# %%
# сохранение данных в файл
all_regions_df.to_csv("data/region_tz.csv", index=False)
